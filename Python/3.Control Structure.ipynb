# %%
age = int(input("enter the age:"))
if(age<18):
        print("kid")
elif(age<35):
    print("adult")
else:
    print("senior")
# Out:
# enter the age: 55
# senior

# %%
lists = [10,32,43,24]

for age in lists:
    if(age<18):
        print("young")
    else:
        print("old")
# Out:
# young
# old
# old
# old
