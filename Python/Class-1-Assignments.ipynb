# %%
#Create a class and function, and list out the items in the list

# %%
class SubfieldsInAI:
    def Subfields():
        lists = ["Machine Learning", "Neural networks", "Vision", "Robotics", "Speech Processing", "Natural Language Processing"]
        print("Sub-fields in AI are:")
        for item in lists:
            print(item)

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
#Create a class and function that checks whether the giver number is Odd or Even

# %%
class OddEven:
    def OddEven():
        num=int(input("Enter the number:"))
        if(num%2==0):
            print(num,"is Even number")
            message="is Even number"
        else:
            print(num,"is Odd number")
            message="is Odd number"
            return message

# %%
OddEven.OddEven()
# Out:
# Enter the number: 52452
# 52452 is Even number

# %%
#Create a funtion that tells eligibilty of marriage for male and female according to their age limit like 21 for male and 18 for female

# %%
def eligible():
    gender=input("your gender")
    age=int(input("your age"))
    if gender=="Male" and age>21:
        print("Eligible")
        message= "Eligible"
    elif gender=="Female" and age>18:
        print("Eligible")
        message= "Eligible"
    else:
        print("Not Eligible")
        message= "Not Eligible"
    return message

# %%
marriage=eligible()
# Out:
# your gender Male
# your age 20
# Not Eligible

# %%
if (marriage=="Eligible"):
    print("Proceed")
else:
    print("Ignore")
# Out:
# Ignore

# %%
#Calculate the percentage of your 10th mark

# %%
class Percent():
    def percentage():
        Sub1= int(input("Subject1= "))
        Sub2= int(input("Subject2= "))
        Sub3= int(input("Subject3= "))
        Sub4= int(input("Subject4= "))
        Sub5= int(input("Subject5= "))
        Total=Sub1+Sub2+Sub3+Sub4+Sub5
        print("Total :",Total)
        Percentage = (Total/500)* 100
        print ("Percentage :",f"{Percentage}")

# %%
Percent.percentage()
# Out:
# Subject1=  98
# Subject2=  87
# Subject3=  95
# Subject4=  95
# Subject5=  93
# Total : 468
# Percentage : 93.60000000000001

# %%
#print area and perimeter of triangle using functions

# %%
class triangle():
    def triangle():
        Height=int(input("Height:"))
        Breadth=int(input("Breadth:"))
        Area = (Height*Breadth)/2
        print("Area formula: (Height*Breadth)/2 ")
        print("Area of triangle:", Area)
        
        H1=int(input("Height1:"))
        H2=int(input("Height2:"))
        B1=int(input("Breadth:"))
        Perimeter = H1+H2+B1
        print("Perimeter formula: Height1+Height2+Breadth ")
        print("Perimeter of triangle:",Perimeter)
        return Area, Perimeter

# %%
triangle.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of triangle: 10
# (544.0, 10)
